# %%
import numpy as np

# %%
sea_state_ps = np.loadtxt("sea_state_ps.txt", delimiter=' ')

# %%
sea_state_ps
# Out:
# array([[1.51666667e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.55000000e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.58333333e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.61666667e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.65000000e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.68333333e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.71666667e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.75000000e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.78333333e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.81666667e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.85000000e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.88333333e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.91666667e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.95000000e+01, 4.53333333e+00, 0.00000000e+00],
#        [1.98333333e+01, 4.53333333e+00, 0.00000000e+00],
#        [2.01666667e+01, 4.53333333e+00, 0.00000000e+00],
# ...
